# %%
import torch
# %matplotlib inline
import matplotlib.pyplot as plt
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lee Geonju\\Desktop\\drone'

# %%
ckpt = torch.load('./collect/simple_a_v2/3v9314lc_rollout0.pt')

# %%
for state in ckpt['states']:
    plt.figure(figsize=(2,2))
    plt.imshow(state)
    plt.show()
